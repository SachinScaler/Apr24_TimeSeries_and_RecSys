# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinScaler/Apr24_TimeSeries_and_RecSys/blob/main/Pandas_4%7CLecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 14.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 5.02MB/s]

# %%
import pandas as pd
import numpy as np

movies = pd.read_csv('movies.csv', index_col=0)
directors = pd.read_csv('directors.csv', index_col=0)

data = movies.merge(directors, how='left', left_on='director_id', right_on='id')
data.drop(['director_id','id_y'], axis=1, inplace=True)

# %% [markdown]
# - Productivity: num_movies/num_year
#     - no of movies
#     - number of years:(max-year - min -year)
#         - min_year
#         - max_year

# %%
data_agg = data.groupby(['director_name']) \
            [["year", "title"]].aggregate(
                {"year":['min','max'], "title": "count"}
                )
data_agg
# Out:
#                              year       title
#                               min   max count
# director_name
# Adam McKay                   2004  2015     6
# Adam Shankman                2001  2012     8
# Alejandro González Iñárritu  2000  2015     6
# Alex Proyas                  1994  2016     5
# Alexander Payne              1999  2013     5
# ...                           ...   ...   ...
# Wes Craven                   1984  2011    10
# Wolfgang Petersen            1981  2006     7
# Woody Allen                  1977  2013    18
# Zack Snyder                  2004  2016     7
# Zhang Yimou                  2002  2014     6
#
# [199 rows x 3 columns]

# %%
data_agg['year']
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %% [markdown]
# - multi-indexing: more than one level of index

# %% [markdown]
# ['year']['max'] -> ['year_max']

# %%
data.columns
# Out:
# Index(['id_x', 'budget', 'popularity', 'revenue', 'title', 'vote_average',
#        'vote_count', 'year', 'month', 'day', 'director_name', 'gender'],
#       dtype='object')

# %%
data_agg.columns
# Out:
# MultiIndex([( 'year',   'min'),
#             ( 'year',   'max'),
#             ('title', 'count')],
#            )

# %%
new_cols = [year + '_' + agg for year, agg in data_agg.columns]
new_cols
# Out:
# ['year_min', 'year_max', 'title_count']

# %%
data_agg.columns = new_cols
data_agg
# Out:
#                              year_min  year_max  title_count
# director_name
# Adam McKay                       2004      2015            6
# Adam Shankman                    2001      2012            8
# Alejandro González Iñárritu      2000      2015            6
# Alex Proyas                      1994      2016            5
# Alexander Payne                  1999      2013            5
# ...                               ...       ...          ...
# Wes Craven                       1984      2011           10
# Wolfgang Petersen                1981      2006            7
# Woody Allen                      1977      2013           18
# Zack Snyder                      2004      2016            7
# Zhang Yimou                      2002      2014            6
#
# [199 rows x 3 columns]

# %% [markdown]
# inbuilt method from groupby:
#  in agg:
#     - col_name = ('col_to_agg', 'aggop',

# %%
data.groupby('director_name')[['year', 'title']].aggregate(
    year_max=('year','max'),
    year_min=('year','min'),
    title_count=('title','count')
)
# Out:
#                              year_max  year_min  title_count
# director_name
# Adam McKay                       2015      2004            6
# Adam Shankman                    2012      2001            8
# Alejandro González Iñárritu      2015      2000            6
# Alex Proyas                      2016      1994            5
# Alexander Payne                  2013      1999            5
# ...                               ...       ...          ...
# Wes Craven                       2011      1984           10
# Wolfgang Petersen                2006      1981            7
# Woody Allen                      2013      1977           18
# Zack Snyder                      2016      2004            7
# Zhang Yimou                      2014      2002            6
#
# [199 rows x 3 columns]

# %%
data.groupby(['director_name'])[["year", "title"]].aggregate(
            {"year":['min','max'], "title": "count"}
                )
# Out:
#                              year       title
#                               min   max count
# director_name
# Adam McKay                   2004  2015     6
# Adam Shankman                2001  2012     8
# Alejandro González Iñárritu  2000  2015     6
# Alex Proyas                  1994  2016     5
# Alexander Payne              1999  2013     5
# ...                           ...   ...   ...
# Wes Craven                   1984  2011    10
# Wolfgang Petersen            1981  2006     7
# Woody Allen                  1977  2013    18
# Zack Snyder                  2004  2016     7
# Zhang Yimou                  2002  2014     6
#
# [199 rows x 3 columns]

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# ...

# %% [markdown]
# HW: Set director_name and year together as index

# %%
# !gdown 173A59xh2mnpmljCCB9bhC4C5eP2IS6qZ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=173A59xh2mnpmljCCB9bhC4C5eP2IS6qZ
# To: /content/Pfizer_1.csv
# 100% 1.51k/1.51k [00:00<00:00, 6.22MB/s]

# %%
data = pd.read_csv('Pfizer_1.csv')
data.head()
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3  15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0      NaN     21.0     21.0       22     23.0     21.0     22.0        20
# 1      NaN     11.0     13.0       14     16.0     16.0     24.0        18
# 2     18.0      NaN     17.0       18      NaN      NaN     23.0        23
# 3     22.0      NaN     22.0       23      NaN      NaN     27.0        26
# 4      NaN     27.0      NaN       26     25.0     24.0     23.0        22
#
#    11:30:00  12:30:00
# 0      20.0        21
# 1      19.0        20
# 2      25.0        25
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       18 non-null     object
#  1   Drug_Name  18 non-null     object
#  2   Parameter  18 non-null     object
#  3   1:30:00    16 non-null     float64
#  4   2:30:00    16 non-null     float64
#  5   3:30:00    12 non-null     float64
#  6   4:30:00    14 non-null     float64
#  7   5:30:00    16 non-null     float64
#  8   6:30:00    18 non-null     int64
#  9   7:30:00    16 non-null     float64
#  10  8:30:00    14 non-null     float64
#  11  9:30:00    16 non-null     float64
#  12  10:30:00   18 non-null     int64
#  13  11:30:00   16 non-null     float64
#  14  12:30:00   18 non-null     int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 2.2+ KB

# %%
data.isna().sum() # pandas 5
# Out:
# Date         0
# Drug_Name    0
# Parameter    0
# 1:30:00      2
# 2:30:00      2
# 3:30:00      6
# 4:30:00      4
# 5:30:00      2
# 6:30:00      0
# 7:30:00      2
# 8:30:00      4
# 9:30:00      2
# 10:30:00     0
# 11:30:00     2
# 12:30:00     0
# dtype: int64

# %% [markdown]
# - melting

# %%
pd.melt(data, id_vars=['Date', 'Parameter', 'Drug_Name'])
# Out:
#            Date    Parameter                Drug_Name  variable  value
# 0    15-10-2020  Temperature  diltiazem hydrochloride   1:30:00   23.0
# 1    15-10-2020     Pressure  diltiazem hydrochloride   1:30:00   12.0
# 2    15-10-2020  Temperature      docetaxel injection   1:30:00    NaN
# 3    15-10-2020     Pressure      docetaxel injection   1:30:00    NaN
# 4    15-10-2020  Temperature   ketamine hydrochloride   1:30:00   24.0
# ..          ...          ...                      ...       ...    ...
# 211  17-10-2020     Pressure  diltiazem hydrochloride  12:30:00   14.0
# 212  17-10-2020  Temperature      docetaxel injection  12:30:00   23.0
# 213  17-10-2020     Pressure      docetaxel injection  12:30:00   28.0
# 214  17-10-2020  Temperature   ketamine hydrochloride  12:30:00   24.0
# 215  17-10-2020     Pressure   ketamine hydrochloride  12:30:00   15.0
#
# [216 rows x 5 columns]

# %%
data_melt = pd.melt(data,
                    id_vars = ['Date', 'Drug_Name', 'Parameter'],
                    var_name = "time",
                    value_name = 'reading')
data_melt
# Out:
#            Date                Drug_Name    Parameter      time  reading
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00     23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00     12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00      NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00      NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00     24.0
# ..          ...                      ...          ...       ...      ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00     14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00     23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00     28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00     24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00     15.0
#
# [216 rows x 5 columns]

# %%
data_melt[data_melt['Drug_Name']=='diltiazem hydrochloride']
# Out:
#            Date                Drug_Name    Parameter      time  reading
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00     23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00     12.0
# 6    16-10-2020  diltiazem hydrochloride  Temperature   1:30:00     34.0
# 7    16-10-2020  diltiazem hydrochloride     Pressure   1:30:00     18.0
# 12   17-10-2020  diltiazem hydrochloride  Temperature   1:30:00     20.0
# ..          ...                      ...          ...       ...      ...
# 199  15-10-2020  diltiazem hydrochloride     Pressure  12:30:00     20.0
# 204  16-10-2020  diltiazem hydrochloride  Temperature  12:30:00     42.0
# 205  16-10-2020  diltiazem hydrochloride     Pressure  12:30:00     27.0
# 210  17-10-2020  diltiazem hydrochloride  Temperature  12:30:00     10.0
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00     14.0
#
# [72 rows x 5 columns]

# %%
data.head()
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3  15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0      NaN     21.0     21.0       22     23.0     21.0     22.0        20
# 1      NaN     11.0     13.0       14     16.0     16.0     24.0        18
# 2     18.0      NaN     17.0       18      NaN      NaN     23.0        23
# 3     22.0      NaN     22.0       23      NaN      NaN     27.0        26
# 4      NaN     27.0      NaN       26     25.0     24.0     23.0        22
#
#    11:30:00  12:30:00
# 0      20.0        21
# 1      19.0        20
# 2      25.0        25
# ...

# %% [markdown]
# ### Can we use a list of columns like ["Date", "Parameter"] for the var_name parameter in pd.melt() on our Pfizer dataset?

# %%
pd.melt(data,
        id_vars = ['Date', 'Drug_Name', 'Parameter'],
        var_name = "time", # ["Date", "Parameter"] not possible
        value_name = 'reading')
# Out:
#            Date                Drug_Name    Parameter      time  reading
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00     23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00     12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00      NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00      NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00     24.0
# ..          ...                      ...          ...       ...      ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00     14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00     23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00     28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00     24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00     15.0
#
# [216 rows x 5 columns]

# %%
# data.columns = list_of_cols
data_melt
# Out:
#            Date                Drug_Name    Parameter      time  reading
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00     23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00     12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00      NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00      NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00     24.0
# ..          ...                      ...          ...       ...      ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00     14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00     23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00     28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00     24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00     15.0
#
# [216 rows x 5 columns]

# %% [markdown]
# Let's try to get our original df back

# %%
data_pivot = data_melt.pivot(
    index=['Date','Drug_Name','Parameter'],  # Columns used to make new frame’s index
    columns='time',   # Column used to make new frame’s columns
    values='reading'    # Column used for populating new frame’s values.
    )

# %%
data_pivot
# Out:
# time                                            10:30:00  11:30:00  12:30:00  \
# Date       Drug_Name               Parameter
# 15-10-2020 diltiazem hydrochloride Pressure         18.0      19.0      20.0
#                                    Temperature      20.0      20.0      21.0
#            docetaxel injection     Pressure         26.0      29.0      28.0
#                                    Temperature      23.0      25.0      25.0
#            ketamine hydrochloride  Pressure          9.0       9.0      11.0
#                                    Temperature      22.0      21.0      20.0
# 16-10-2020 diltiazem hydrochloride Pressure         24.0       NaN      27.0
#                                    Temperature      40.0       NaN      42.0
#            docetaxel injection     Pressure         28.0      29.0      30.0
#                                    Temperature      56.0      57.0      58.0
#            ketamine hydrochloride  Pressure         16.0      17.0      18.0
# ...

# %%
data_tidy = data_pivot.reset_index()
data_tidy
# Out:
# time        Date                Drug_Name    Parameter  10:30:00  11:30:00  \
# 0     15-10-2020  diltiazem hydrochloride     Pressure      18.0      19.0
# 1     15-10-2020  diltiazem hydrochloride  Temperature      20.0      20.0
# 2     15-10-2020      docetaxel injection     Pressure      26.0      29.0
# 3     15-10-2020      docetaxel injection  Temperature      23.0      25.0
# 4     15-10-2020   ketamine hydrochloride     Pressure       9.0       9.0
# 5     15-10-2020   ketamine hydrochloride  Temperature      22.0      21.0
# 6     16-10-2020  diltiazem hydrochloride     Pressure      24.0       NaN
# 7     16-10-2020  diltiazem hydrochloride  Temperature      40.0       NaN
# 8     16-10-2020      docetaxel injection     Pressure      28.0      29.0
# 9     16-10-2020      docetaxel injection  Temperature      56.0      57.0
# 10    16-10-2020   ketamine hydrochloride     Pressure      16.0      17.0
# ...

# %%
data_pivot.loc['16-10-2020']
# Out:
# time                                 10:30:00  11:30:00  12:30:00  1:30:00  \
# Drug_Name               Parameter
# diltiazem hydrochloride Pressure         24.0       NaN      27.0     18.0
#                         Temperature      40.0       NaN      42.0     34.0
# docetaxel injection     Pressure         28.0      29.0      30.0     23.0
#                         Temperature      56.0      57.0      58.0     46.0
# ketamine hydrochloride  Pressure         16.0      17.0      18.0     12.0
#                         Temperature      13.0      14.0      15.0      8.0
#
# time                                 2:30:00  3:30:00  4:30:00  5:30:00  \
# Drug_Name               Parameter
# diltiazem hydrochloride Pressure        19.0     20.0     21.0     22.0
#                         Temperature     35.0     36.0     36.0     37.0
# docetaxel injection     Pressure        24.0      NaN     25.0     26.0
#                         Temperature     47.0      NaN     48.0     48.0
# ...

# %%
data_pivot.loc['16-10-2020'].loc['diltiazem hydrochloride']
# Out:
# time         10:30:00  11:30:00  12:30:00  1:30:00  2:30:00  3:30:00  4:30:00  \
# Parameter
# Pressure         24.0       NaN      27.0     18.0     19.0     20.0     21.0
# Temperature      40.0       NaN      42.0     34.0     35.0     36.0     36.0
#
# time         5:30:00  6:30:00  7:30:00  8:30:00  9:30:00
# Parameter
# Pressure        22.0     23.0     24.0     25.0     25.0
# Temperature     37.0     38.0     37.0     38.0     39.0

# %% [markdown]
# ### Break HW
#
# try this and explain what is teh problem with this code:
#
# Q1: Can you pivot the melted data and convert Parameter values as columns?
# You can store the output in data_tidy
#
# Q2: What is the issue with following code:
# ```
# data_tidy.pivot(index=['Drug_Name'],
# columns = 'Date',
# values=['Temperature'])
#
# ```

# %%
data_melt
# Out:
#            Date                Drug_Name    Parameter      time  reading
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00     23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00     12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00      NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00      NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00     24.0
# ..          ...                      ...          ...       ...      ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00     14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00     23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00     28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00     24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00     15.0
#
# [216 rows x 5 columns]

# %%
data_tidy = data_melt.pivot(
    index=['Date','Drug_Name','time'],  # Columns used to make new frame’s index
    columns='Parameter',   # Column used to make new frame’s columns
    values='reading'    # Column used for populating new frame’s values.
    ).reset_index()
data_tidy
# Out:
# Parameter        Date                Drug_Name      time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 20.0
# 2                 21.0
# 3                 23.0
# 4                 22.0
# ...

# %%
data_tidy[data_tidy['Drug_Name']=='diltiazem hydrochloride'].Pressure.head()
# Out:
# 0    18.0
# 1    19.0
# 2    20.0
# 3    12.0
# 4    13.0
# Name: Pressure, dtype: float64

# %%
data_tidy.head()
# Out:
# Parameter        Date                Drug_Name      time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 20.0
# 2                 21.0
# 3                 23.0
# 4                 22.0

# %%
data_tidy.pivot(index=['Drug_Name'],
                columns = 'Date',
                values=['Temperature'],
                )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-02196307c67d> in <cell line: 1>()
# ----> 1 data_tidy.pivot(index=['Drug_Name'],
#       2                 columns = 'Date',
#       3                 values=['Temperature'],
#       4                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in pivot(self, columns, index, values)
#    9023         from pandas.core.reshape.pivot import pivot
#    9024
# -> 9025         return pivot(self, index=index, columns=columns, values=values)
#    9026
#    9027     _shared_docs[
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in pivot(data, columns, index, values)
#     551     # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     552     # "Hashable"
# --> 553     result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
# ...

# %%
pd.pivot_table(data_tidy,
               index='Drug_Name',
               columns='Date',
               values=['Temperature'],
               aggfunc=np.mean) # Duplicate index will be aggregated
# Out:
# <ipython-input-68-3614561f2139>:1: FutureWarning: The provided callable <function mean at 0x79a8b1d17d90> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pd.pivot_table(data_tidy,
# Parameter               Temperature
# Date                     15-10-2020 16-10-2020 17-10-2020
# Drug_Name
# diltiazem hydrochloride   21.454545  37.454545  15.636364
# docetaxel injection       20.750000  51.454545  17.500000
# ketamine hydrochloride    23.555556  11.500000  18.500000

# %%
data_tidy.head()
# Out:
# Parameter        Date                Drug_Name      time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 20.0
# 2                 21.0
# 3                 23.0
# 4                 22.0

# %%
data_tidy.Temperature.min()
# Out:
# 8.0

# %%
data_tidy.Temperature.max()
# Out:
# 58.0

# %%
temp_points = [5, 20, 35, 50, 60]

temp_labels = ['low','medium','high','very_high'] # labels define the severity of the resultant output of the

# %%
def func_cat(x):
    if 5 < x <=20:
        return "low"
    elif 20 < x <= 35:
        return "medium"
    elif 35 < x <= 50:
        return "high"
    else:
        return "very_high"

data_tidy['label_with_apply'] = data_tidy.Temperature.apply(func_cat)
data_tidy.head()
# Out:
# Parameter        Date                Drug_Name      time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
#
# Parameter  Temperature label_with_apply
# 0                 20.0              low
# 1                 20.0              low
# 2                 21.0           medium
# 3                 23.0           medium
# 4                 22.0           medium

# %%
# x = 20
# 5 < x <= 20

# %% [markdown]
# ### Binning

# %%
temp_points = [5, 20, 35, 50, 60]

temp_labels = ['low','medium','high','very_high'] # labels define the severity of the resultant output of the test

data_tidy['temp_cat'] = pd.cut(data_tidy['Temperature'], # col on which bin to be performed
                               bins=temp_points, # bin values as list
                               labels=temp_labels) # label_values to be created
data_tidy.head()
# Out:
# Parameter        Date                Drug_Name      time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
#
# Parameter  Temperature label_with_apply temp_cat
# 0                 20.0              low      low
# 1                 20.0              low      low
# 2                 21.0           medium   medium
# 3                 23.0           medium   medium
# 4                 22.0           medium   medium

# %%
def func_cat(x):
    if 5 < x <= 20:
        return "low"
    elif 20 < x <= 35:
        return "medium"
    elif 35 < x <= 50:
        return "high"
    else:
        return "very_high"

# %% [markdown]
# https://www.scaler.com/hire/test/problem/101485/

# %%
data_tidy['Temperature'].fillna(1) # replace nan with 0
# Out:
# 0      20.0
# 1      20.0
# 2      21.0
# 3      23.0
# 4      22.0
#        ...
# 103    17.0
# 104    18.0
# 105    19.0
# 106    20.0
# 107    21.0
# Name: Temperature, Length: 108, dtype: float64

# %% [markdown]
# ```
# | -> or
# & -> and
#
# ```

# %%
# mask = (df['Stream']=='Commerce') | (df['Stream']=='Arts'))

# df_new = df[mask]
# mask = df_new['Percentage'] >=75
# df_new = df_new[mask]

# %%
df = pd.DataFrame({"Gender": ["M", "F", "M"]})
df
# Out:
#   Gender
# 0      M
# 1      F
# 2      M

# %%
df['Gender'].map({'M':0, 'F':1}) #
# Out:
# 0    0
# 1    1
# 2    0
# Name: Gender, dtype: int64

# %%
#

# %% [markdown]
# Filtering on Groups:
